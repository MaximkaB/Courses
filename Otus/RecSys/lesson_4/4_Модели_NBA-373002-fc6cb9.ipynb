# %% [markdown]
# Задачу NBA будем решать на синтетическом датасете. В данных содержится информация о клиентах вымышленного интернет-магазина, которым рекламировали Ноутбук (б/у, очень старый), Телефон или Зарядное устройство.
#
# **Задача**: построить модель NBA как композицию бинарный моделей отклика и сравить лучшее предложение на основе вероятностей с лучшим предложением с учетом NPV продукта.

# %% [markdown]
# # Загрузка и подготовка данных

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.utils import shuffle

import warnings
warnings.filterwarnings("ignore")

# Установка настроек для отображения всех колонок и строк при печати
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# заранее установим в константу random_state
random_state = 47

sns.set(style="whitegrid")

# %%
df_Laptop = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/OTUS/synthetic_laptop_data.csv')
df_Charger = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/OTUS/synthetic_charger_data.csv')
df_Phone = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/OTUS/synthetic_mobile_phone_data.csv')

df = pd.concat([df_Laptop, df_Charger, df_Phone])
print(df.shape)
df.head()
# Out:
# (30000, 18)
#    Age  Gender      Geography  PreviousPurchases         Salary  NumChildren  \
# 0   56    Male  North America        8386.985501   42217.503431            4
# 1   69  Female  South America        7391.924025   44369.165492            3
# 2   46  Female  South America        7951.832329   85406.301432            3
# 3   32  Female         Africa        2284.841225  116197.240945            4
# 4   60    Male           Asia        6520.780649   55461.014410            0
#
#   Product EducationLevel MaritalStatus EmploymentStatus        HousingStatus  \
# 0  Laptop       Bachelor      Divorced         Employed                 Rent
# 1  Laptop         Master        Single         Employed                  Own
# 2  Laptop    High School       Widowed       Unemployed                  Own
# 3  Laptop            PhD       Widowed          Retired  Living with Parents
# 4  Laptop    High School       Married         Employed  Living with Parents
#
#    CreditScore  InternetUsage  NumberOfCars HealthStatus  ShoppingFrequency  \
# 0          754       1.545836             0         Fair                  6
# 1          745       8.005712             0         Good                  1
# 2          552       8.154606             1         Fair                  5
# 3          458       1.938812             1         Fair                 17
# 4          434       7.656888             0         Fair                 10
#
#    MembershipDuration  PurchaseFlag
# 0                   9             1
# 1                   3             1
# 2                   9             0
# 3                   2             1
# 4                  15             0

# %% [markdown]
# Описание фичей:
#
# **Age**: Возраст клиента
#
# **Gender**: Пол клиента
#
# **Geography**: Регион проживания клиента
#
# **PreviousPurchases**: Сумма предыдущих покупок клиента в валюте
#
# **Salary**: Годовая зарплата клиента в валюте
#
# **NumChildren**: Количество детей у клиента
#
# **Product**: Продукт, который рассматривается для покупки
#
# **EducationLevel**: Уровень образования клиента
#
# **MaritalStatus**: Семейное положение клиента
#
# **EmploymentStatus**: Статус занятости клиента
#
# **HousingStatus**: Жилищный статус клиента
#
# **CreditScore**: Кредитный рейтинг клиента
#
# **InternetUsage**: Время, проведенное в интернете, в часах в день
#
# **NumberOfCars**: Количество автомобилей у клиента
#
# **HealthStatus**: Состояние здоровья клиента
#
# **ShoppingFrequency**: Частота покупок клиента, количество покупок в месяц
#
# **MembershipDuration**: Длительность членства клиента в годах
#
# **PurchaseFlag**: Флаг покупки, указывает на то, совершил ли клиент покупку
#
# Эти фичи содержат демографические данные клиентов, а также их покупательские и финансовые характеристики, которые используются для предсказания вероятности покупки продукта.

# %%
df.groupby(['Product', 'PurchaseFlag']).agg({'Gender': 'count'})
# Out:
#                            Gender
# Product      PurchaseFlag
# Charger      0               6541
#              1               3459
# Laptop       0               4594
#              1               5406
# Mobile Phone 0               5049
#              1               4951

# %%
df.groupby(['Product']).agg({'PurchaseFlag': 'mean'})
# Out:
#               PurchaseFlag
# Product
# Charger             0.3459
# Laptop              0.5406
# Mobile Phone        0.4951

# %% [markdown]
# NPV зададим следующим образом:

# %%
npv_values = {
    'Laptop': 100.0,
    'Phone': 300.0,
    'Charger': 200.0
}

# %% [markdown]
# ## Кодирование

# %% [markdown]
# Обучаться будем на бустинге. CatBoost гибок к типам данных. Это значит, что можно не заниматься кодиррванием переменных, а просто присвоить категориальный тип данных.

# %%
object_cols = list(df.drop(['Product'], axis=1).select_dtypes('object').columns)
print(f'we have {len(object_cols)} object_cols')

df[object_cols] = df[object_cols].astype('category')
# Out:
# we have 7 object_cols

# %% [markdown]
# ## Семплирование

# %%
df = df.rename(columns={'PurchaseFlag': 'target'})

# %%
df_Charger = df[df['Product'] == 'Charger']
df_Laptop = df[df['Product'] == 'Laptop']
df_Phone = df[df['Product'] == 'Mobile Phone']

print(f"Размеры датасетов:\n"
      f"Charger: {df_Charger.shape[0]} записей и {df_Charger.shape[1]} фичей\n"
      f"Laptop: {df_Laptop.shape[0]} записей и {df_Laptop.shape[1]} фичей\n"
      f"Mobile Phone: {df_Phone.shape[0]} записей и {df_Phone.shape[1]} фичей\n")

print(f"Средняя доля покупок:\n"
      f"Charger: {df_Charger.target.mean():.2f}\n"
      f"Laptop: {df_Laptop.target.mean():.2f}\n"
      f"Mobile Phone: {df_Phone.target.mean():.2f}\n")
# Out:
# Размеры датасетов:
# Charger: 10000 записей и 18 фичей
# Laptop: 10000 записей и 18 фичей
# Mobile Phone: 10000 записей и 18 фичей
#
# Средняя доля покупок:
# Charger: 0.35
# Laptop: 0.54
# Mobile Phone: 0.50

# %%
features_Charger = df_Charger.drop(['Product', 'target'], axis=1)
target_Charger = df_Charger['target']

features_Laptop = df_Laptop.drop(['Product', 'target'], axis=1)
target_Laptop = df_Laptop['target']

features_Phone = df_Phone.drop(['Product', 'target'], axis=1)
target_Phone = df_Phone['target']

# %%
def make_samples(features, target):
  # отделяем 20% - пятую часть всего - на тестовую выборку
  X_train_valid, X_test, y_train_valid, y_test = train_test_split(features, target,
                                                                  test_size=0.2,
                                                                  random_state=random_state)
  # отделяем 25% - четвертую часть трейн+валид - на валидирующую выборку
  X_train, X_valid, y_train, y_valid = train_test_split(X_train_valid, y_train_valid,
                                                        test_size=0.25,
                                                        random_state=random_state)

  s1 = y_train.size
  s2 = y_valid.size
  s3 = y_test.size
  print('Разбиение на выборки train:valid:test в соотношении '
        + str(round(s1/s3)) + ':' + str(round(s2/s3)) + ':' + str(round(s3/s3)))
  print('target rate на разбиениях:', round(y_train.mean(), 4), round(y_valid.mean(), 4), round(y_test.mean(), 4))
  return X_train, X_valid, X_test, y_train, y_valid, y_test

# %%
X_train_Charger, X_valid_Charger, X_test_Charger, y_train_Charger, y_valid_Charger, y_test_Charger = make_samples(features_Charger, target_Charger)
X_train_Laptop, X_valid_Laptop, X_test_Laptop, y_train_Laptop, y_valid_Laptop, y_test_Laptop = make_samples(features_Laptop, target_Laptop)
X_train_Phone, X_valid_Phone, X_test_Phone, y_train_Phone, y_valid_Phone, y_test_Phone = make_samples(features_Phone, target_Phone)
# Out:
# Разбиение на выборки train:valid:test в соотношении 3:1:1
# target rate на разбиениях: 0.3532 0.3325 0.3375
# Разбиение на выборки train:valid:test в соотношении 3:1:1
# target rate на разбиениях: 0.5388 0.549 0.5375
# Разбиение на выборки train:valid:test в соотношении 3:1:1
# target rate на разбиениях: 0.4938 0.506 0.488

# %%
X_train_Charger.head(2)
# Out:
#       Age  Gender      Geography  PreviousPurchases        Salary  \
# 9731   23  Female  South America        6042.440703  67691.979045
# 6920   64    Male  North America        2497.156731  35648.888199
#
#       NumChildren EducationLevel MaritalStatus EmploymentStatus  \
# 9731            2         Master        Single          Student
# 6920            1    High School       Widowed          Student
#
#             HousingStatus  CreditScore  InternetUsage  NumberOfCars  \
# 9731  Living with Parents          655       4.588958             0
# 6920                 Rent          379       6.842913             0
#
#      HealthStatus  ShoppingFrequency  MembershipDuration
# 9731         Poor                  2                  11
# 6920         Poor                 11                   1

# %% [markdown]
# # Вспомогательные функции

# %%
# Функция для оценки модели
def calc_metrics(model, X_train, y_train, X_valid, y_valid, X_test, y_test):
    # Обучение
    y_train_pred = model.predict(X_train)
    y_train_proba = model.predict_proba(X_train)[:, 1] if hasattr(model, 'predict_proba') else model.decision_function(X_train)

    # Валидация
    y_valid_pred = model.predict(X_valid)
    y_valid_proba = model.predict_proba(X_valid)[:, 1] if hasattr(model, 'predict_proba') else model.decision_function(X_valid)

    # Тестирование
    y_test_pred = model.predict(X_test)
    y_test_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, 'predict_proba') else model.decision_function(X_test)

    train_metrics = {
        'precision': precision_score(y_train, y_train_pred),
        'recall': recall_score(y_train, y_train_pred),
        'f1': f1_score(y_train, y_train_pred),
        'roc_auc': roc_auc_score(y_train, y_train_proba)
    }

    valid_metrics = {
        'precision': precision_score(y_valid, y_valid_pred),
        'recall': recall_score(y_valid, y_valid_pred),
        'f1': f1_score(y_valid, y_valid_pred),
        'roc_auc': roc_auc_score(y_valid, y_valid_proba)
    }

    test_metrics = {
        'precision': precision_score(y_test, y_test_pred),
        'recall': recall_score(y_test, y_test_pred),
        'f1': f1_score(y_test, y_test_pred),
        'roc_auc': roc_auc_score(y_test, y_test_proba)
    }

    return train_metrics, valid_metrics, test_metrics

def print_metrics(model, X_train, y_train, X_valid, y_valid, X_test, y_test):
    res = calc_metrics(model, X_train, y_train, X_valid, y_valid, X_test, y_test)
    metrics = pd.DataFrame(res, index=['train', 'valid', 'test'])
    return metrics

# %% [markdown]
# # Train models

# %% [markdown]
# https://catboost.ai/en/docs/concepts/python-reference_catboostclassifier

# %%
# !pip install catboost optuna
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.5)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)

# %%
from catboost import CatBoostClassifier
import optuna

# %%
def objective(trial, X_train, y_train, X_valid, y_valid):
    param = {
        "learning_rate": trial.suggest_float('learning_rate', 0.01, 0.9),
        "max_depth": trial.suggest_int("max_depth", 2, 7),
        "l2_leaf_reg":trial.suggest_float('l2_leaf_reg', 0.01, 2),
        "subsample": trial.suggest_float('subsample', 0.01, 1),
        "random_strength": trial.suggest_float('random_strength', 1, 200),
        "min_data_in_leaf":trial.suggest_float('min_data_in_leaf', 1, 500)
    }

    cat = CatBoostClassifier(
        logging_level="Silent",
        eval_metric="AUC",
        grow_policy="Lossguide",
        random_seed=42,
        **param)
    cat.fit(X_train, y_train, cat_features=object_cols,
            eval_set=(X_valid, y_valid),
            verbose=False,
            early_stopping_rounds=10
           )

    preds = cat.predict_proba(X_valid)[:,1]
    auc = roc_auc_score(y_valid, preds)

    return auc

# %%
def train_model(X_train, y_train, X_valid, y_valid, X_test, y_test):

  study = optuna.create_study(direction="maximize", study_name='CatBoostClassifier')
  study.optimize(lambda trial: objective(trial, X_train, y_train, X_valid, y_valid), n_trials=100)

  best_cat = CatBoostClassifier(**study.best_params, random_state=random_state)
  best_cat.fit(X_train, y_train, cat_features=object_cols,
              eval_set=(X_valid, y_valid),
              verbose=False,
              early_stopping_rounds=10
            )

  res_cat = print_metrics(best_cat, X_train, y_train, X_valid, y_valid, X_test, y_test)
  return res_cat, best_cat

# %%
res_Laptop, model_Laptop = train_model(X_train_Laptop, y_train_Laptop, X_valid_Laptop, y_valid_Laptop, X_test_Laptop, y_test_Laptop)
res_Charger, model_Charger = train_model(X_train_Charger, y_train_Charger, X_valid_Charger, y_valid_Charger, X_test_Charger, y_test_Charger)
res_Phone, model_Phone = train_model(X_train_Phone, y_train_Phone, X_valid_Phone, y_valid_Phone, X_test_Phone, y_test_Phone)
# Out:
# [I 2024-06-13 18:47:52,458] A new study created in memory with name: CatBoostClassifier
# [I 2024-06-13 18:47:53,152] Trial 0 finished with value: 0.6820281988214815 and parameters: {'learning_rate': 0.7843864039274303, 'max_depth': 6, 'l2_leaf_reg': 0.09582490629611397, 'subsample': 0.23996090299613035, 'random_strength': 165.89234306358253, 'min_data_in_leaf': 349.41643330950427}. Best is trial 0 with value: 0.6820281988214815.
# [I 2024-06-13 18:47:54,409] Trial 1 finished with value: 0.683363018428992 and parameters: {'learning_rate': 0.1556715950233523, 'max_depth': 7, 'l2_leaf_reg': 0.5620468279555199, 'subsample': 0.4112719822753225, 'random_strength': 104.52796956020892, 'min_data_in_leaf': 464.0671536231361}. Best is trial 1 with value: 0.683363018428992.
# [I 2024-06-13 18:47:55,472] Trial 2 finished with value: 0.6834129984369888 and parameters: {'learning_rate': 0.47173315601139937, 'max_depth': 3, 'l2_leaf_reg': 0.6987778021992275, 'subsample': 0.579474891442067, 'random_strength': 35.872428108961905, 'min_data_in_leaf': 7.962264042007749}. Best is trial 2 with value: 0.6834129984369888.
# [I 2024-06-13 18:47:56,565] Trial 3 finished with value: 0.6807660774074209 and parameters: {'learning_rate': 0.04723934627607955, 'max_depth': 6, 'l2_leaf_reg': 1.5454483956185927, 'subsample': 0.10389375234170715, 'random_strength': 117.51240157606931, 'min_data_in_leaf': 364.46286302700094}. Best is trial 2 with value: 0.6834129984369888.
# [I 2024-06-13 18:47:57,911] Trial 4 finished with value: 0.6748588443410515 and parameters: {'learning_rate': 0.07250663566629838, 'max_depth': 4, 'l2_leaf_reg': 0.7673270159872465, 'subsample': 0.6507559735937377, 'random_strength': 183.59633955677398, 'min_data_in_leaf': 356.68693114288766}. Best is trial 2 with value: 0.6834129984369888.
# [I 2024-06-13 18:47:59,810] Trial 5 finished with value: 0.6899674473644885 and parameters: {'learning_rate': 0.1675378734972408, 'max_depth': 6, 'l2_leaf_reg': 0.24301659866608166, 'subsample': 0.1409229892570593, 'random_strength': 34.459614762143296, 'min_data_in_leaf': 199.60436604690298}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:00,230] Trial 6 finished with value: 0.6173671945363268 and parameters: {'learning_rate': 0.09760151243845624, 'max_depth': 5, 'l2_leaf_reg': 0.7601511511788908, 'subsample': 0.27689157198001263, 'random_strength': 90.70287365195594, 'min_data_in_leaf': 346.60088270877213}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:00,877] Trial 7 finished with value: 0.6851638132625738 and parameters: {'learning_rate': 0.15847566245665087, 'max_depth': 3, 'l2_leaf_reg': 0.25083660540141645, 'subsample': 0.37930451006981214, 'random_strength': 23.832670052623367, 'min_data_in_leaf': 370.8388530447596}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:01,612] Trial 8 finished with value: 0.6708190461189262 and parameters: {'learning_rate': 0.07430581844978093, 'max_depth': 5, 'l2_leaf_reg': 1.4741426879549513, 'subsample': 0.25984223771292103, 'random_strength': 165.67230447253854, 'min_data_in_leaf': 446.5991981724182}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:02,161] Trial 9 finished with value: 0.6818979478915503 and parameters: {'learning_rate': 0.5471321662471815, 'max_depth': 2, 'l2_leaf_reg': 0.8686455925381276, 'subsample': 0.8721575109075326, 'random_strength': 55.221706246621274, 'min_data_in_leaf': 362.6147149079164}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:02,824] Trial 10 finished with value: 0.6829803432162488 and parameters: {'learning_rate': 0.31903415820955294, 'max_depth': 7, 'l2_leaf_reg': 1.984575569482114, 'subsample': 0.055183060277414694, 'random_strength': 2.8845214999461426, 'min_data_in_leaf': 152.93282812208975}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:03,419] Trial 11 finished with value: 0.6848124386608992 and parameters: {'learning_rate': 0.28438792492735016, 'max_depth': 3, 'l2_leaf_reg': 0.06025780953369858, 'subsample': 0.362017267395494, 'random_strength': 3.2675816214246787, 'min_data_in_leaf': 199.1993452560936}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:05,491] Trial 12 finished with value: 0.6806216907176523 and parameters: {'learning_rate': 0.2755128323070532, 'max_depth': 4, 'l2_leaf_reg': 0.3316387275159061, 'subsample': 0.5117867332156619, 'random_strength': 53.63668354424051, 'min_data_in_leaf': 229.79964535548717}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:06,097] Trial 13 finished with value: 0.6867455038186745 and parameters: {'learning_rate': 0.6854041775167969, 'max_depth': 2, 'l2_leaf_reg': 0.3391863407610138, 'subsample': 0.14184346887600757, 'random_strength': 34.86048295421507, 'min_data_in_leaf': 82.99273332577056}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:06,640] Trial 14 finished with value: 0.6844736852733653 and parameters: {'learning_rate': 0.7174902487911344, 'max_depth': 2, 'l2_leaf_reg': 1.1580255672539872, 'subsample': 0.038673537509406455, 'random_strength': 75.16747418247493, 'min_data_in_leaf': 81.43521116928935}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:07,405] Trial 15 finished with value: 0.6648269984935319 and parameters: {'learning_rate': 0.5843577613397606, 'max_depth': 6, 'l2_leaf_reg': 0.46727166402050746, 'subsample': 0.16823601129752944, 'random_strength': 134.52527958522896, 'min_data_in_leaf': 107.74404266302085}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:08,243] Trial 16 finished with value: 0.6631296976159032 and parameters: {'learning_rate': 0.8670153717995555, 'max_depth': 5, 'l2_leaf_reg': 0.37757752225483354, 'subsample': 0.6818897810974656, 'random_strength': 62.36656634186531, 'min_data_in_leaf': 26.593741441515647}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:09,083] Trial 17 finished with value: 0.6682660269225642 and parameters: {'learning_rate': 0.6552609297585601, 'max_depth': 4, 'l2_leaf_reg': 1.09925205180274, 'subsample': 0.9536213972943732, 'random_strength': 29.550157428631362, 'min_data_in_leaf': 278.1285545536015}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:10,636] Trial 18 finished with value: 0.6755439238446035 and parameters: {'learning_rate': 0.4050986756849077, 'max_depth': 6, 'l2_leaf_reg': 0.21698641382007067, 'subsample': 0.19039704008525193, 'random_strength': 82.06461640530908, 'min_data_in_leaf': 159.2829296088247}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:11,504] Trial 19 finished with value: 0.6771205659150481 and parameters: {'learning_rate': 0.895896368596022, 'max_depth': 2, 'l2_leaf_reg': 0.5515453438356321, 'subsample': 0.13682428014756143, 'random_strength': 38.79208135510515, 'min_data_in_leaf': 84.88718288632387}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:12,798] Trial 20 finished with value: 0.6719807026684276 and parameters: {'learning_rate': 0.4493504084313249, 'max_depth': 7, 'l2_leaf_reg': 0.02564402192418458, 'subsample': 0.7933603736427132, 'random_strength': 130.6381970874205, 'min_data_in_leaf': 274.80707270050345}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:13,704] Trial 21 finished with value: 0.6785871509981866 and parameters: {'learning_rate': 0.174950635393039, 'max_depth': 3, 'l2_leaf_reg': 0.2846311015152253, 'subsample': 0.35884081018899194, 'random_strength': 20.556180159704752, 'min_data_in_leaf': 299.7331164047362}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:14,454] Trial 22 finished with value: 0.6766096591666364 and parameters: {'learning_rate': 0.21666962834829048, 'max_depth': 3, 'l2_leaf_reg': 0.21004650172509826, 'subsample': 0.45342731514259044, 'random_strength': 20.22749380742648, 'min_data_in_leaf': 427.9294279122615}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:15,078] Trial 23 finished with value: 0.5 and parameters: {'learning_rate': 0.010319112689757437, 'max_depth': 2, 'l2_leaf_reg': 0.5396304207247673, 'subsample': 0.016875809691666133, 'random_strength': 46.823160275092256, 'min_data_in_leaf': 186.94219312216512}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:16,060] Trial 24 finished with value: 0.6759669869425968 and parameters: {'learning_rate': 0.34749051461866887, 'max_depth': 3, 'l2_leaf_reg': 0.9352941876625118, 'subsample': 0.3282897491379637, 'random_strength': 16.573444106243088, 'min_data_in_leaf': 114.83249988954516}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:16,870] Trial 25 finished with value: 0.6761598390946651 and parameters: {'learning_rate': 0.19054034050201618, 'max_depth': 2, 'l2_leaf_reg': 0.18368207480169807, 'subsample': 0.2167634843666978, 'random_strength': 69.46670827786086, 'min_data_in_leaf': 227.73317584350536}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:17,715] Trial 26 finished with value: 0.6859771243017945 and parameters: {'learning_rate': 0.5593802350390289, 'max_depth': 4, 'l2_leaf_reg': 0.34274426892254634, 'subsample': 0.1168400913417546, 'random_strength': 42.338086518151094, 'min_data_in_leaf': 405.886605824387}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:18,349] Trial 27 finished with value: 0.6821372461116563 and parameters: {'learning_rate': 0.5844587562114427, 'max_depth': 5, 'l2_leaf_reg': 0.438073712236876, 'subsample': 0.1277714198412501, 'random_strength': 46.83288140738526, 'min_data_in_leaf': 312.15436527888926}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:19,023] Trial 28 finished with value: 0.6690853961445726 and parameters: {'learning_rate': 0.6941039466793466, 'max_depth': 4, 'l2_leaf_reg': 0.6286443798428597, 'subsample': 0.0852264903112334, 'random_strength': 102.19738241781265, 'min_data_in_leaf': 37.63933765666164}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:19,622] Trial 29 finished with value: 0.683553851186798 and parameters: {'learning_rate': 0.7965744862222895, 'max_depth': 6, 'l2_leaf_reg': 1.2795077494665361, 'subsample': 0.2843004950349637, 'random_strength': 64.1408462783246, 'min_data_in_leaf': 414.5735343230972}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:20,101] Trial 30 finished with value: 0.662659683601307 and parameters: {'learning_rate': 0.5177976742831388, 'max_depth': 5, 'l2_leaf_reg': 0.10564302121601418, 'subsample': 0.21352483602369302, 'random_strength': 87.4129137084934, 'min_data_in_leaf': 130.64128782563904}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:20,667] Trial 31 finished with value: 0.6790914947152452 and parameters: {'learning_rate': 0.65246634121462, 'max_depth': 3, 'l2_leaf_reg': 0.3562902739607796, 'subsample': 0.16284291191138286, 'random_strength': 27.733004700815727, 'min_data_in_leaf': 498.64582398139106}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:21,286] Trial 32 finished with value: 0.6837032863622228 and parameters: {'learning_rate': 0.7511719786395497, 'max_depth': 4, 'l2_leaf_reg': 0.15862680874500013, 'subsample': 0.3070380722368885, 'random_strength': 11.953851678322934, 'min_data_in_leaf': 394.7039141817869}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:22,039] Trial 33 finished with value: 0.687358894825908 and parameters: {'learning_rate': 0.38724513550255973, 'max_depth': 3, 'l2_leaf_reg': 0.47236576334160485, 'subsample': 0.4163417831558949, 'random_strength': 35.62558486917174, 'min_data_in_leaf': 479.80110379225783}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:22,768] Trial 34 finished with value: 0.6845625386209153 and parameters: {'learning_rate': 0.4225113570356158, 'max_depth': 2, 'l2_leaf_reg': 0.48856765855962114, 'subsample': 0.440118655294736, 'random_strength': 36.314775364955246, 'min_data_in_leaf': 484.0168123066774}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:23,789] Trial 35 finished with value: 0.6852556957015172 and parameters: {'learning_rate': 0.3665551507192029, 'max_depth': 4, 'l2_leaf_reg': 0.6796026104355717, 'subsample': 0.5398992217607208, 'random_strength': 48.32980189777672, 'min_data_in_leaf': 454.8116847951075}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:24,697] Trial 36 finished with value: 0.6775724053812818 and parameters: {'learning_rate': 0.4931906572723221, 'max_depth': 3, 'l2_leaf_reg': 0.8168976031164235, 'subsample': 0.6360247825668781, 'random_strength': 38.37934994134436, 'min_data_in_leaf': 472.7946857024331}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:25,284] Trial 37 finished with value: 0.6781837769942528 and parameters: {'learning_rate': 0.5979430733122462, 'max_depth': 7, 'l2_leaf_reg': 0.6330107484728678, 'subsample': 0.0945783569126713, 'random_strength': 10.538778430386795, 'min_data_in_leaf': 331.84458308101193}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:26,078] Trial 38 finished with value: 0.6705847963844765 and parameters: {'learning_rate': 0.7895121401691858, 'max_depth': 4, 'l2_leaf_reg': 0.011563648959072026, 'subsample': 0.23242763267600208, 'random_strength': 76.16234409772, 'min_data_in_leaf': 392.6928362477388}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:27,246] Trial 39 finished with value: 0.6789188365058018 and parameters: {'learning_rate': 0.6316308340188873, 'max_depth': 3, 'l2_leaf_reg': 0.4169512116904973, 'subsample': 0.4146948608249122, 'random_strength': 110.94006282141063, 'min_data_in_leaf': 436.78284694078}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:27,931] Trial 40 finished with value: 0.687521456064039 and parameters: {'learning_rate': 0.5357125910141661, 'max_depth': 2, 'l2_leaf_reg': 1.8390673321456703, 'subsample': 0.0706911340753857, 'random_strength': 61.46803130599433, 'min_data_in_leaf': 56.38060250221903}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:28,841] Trial 41 finished with value: 0.6876900754849575 and parameters: {'learning_rate': 0.5425913898802448, 'max_depth': 2, 'l2_leaf_reg': 1.957170009398138, 'subsample': 0.07617436869876248, 'random_strength': 61.68528967678505, 'min_data_in_leaf': 63.90092040046986}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:31,415] Trial 42 finished with value: 0.6852582199443454 and parameters: {'learning_rate': 0.5108734308311413, 'max_depth': 2, 'l2_leaf_reg': 1.9360439917440135, 'subsample': 0.012163187290078405, 'random_strength': 27.096673235370055, 'min_data_in_leaf': 52.39006691998629}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:31,815] Trial 43 finished with value: 0.6843146579751938 and parameters: {'learning_rate': 0.46383086501808946, 'max_depth': 2, 'l2_leaf_reg': 1.8410321425533425, 'subsample': 0.07931618598330654, 'random_strength': 57.46288725899932, 'min_data_in_leaf': 58.81986851179854}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:32,087] Trial 44 finished with value: 0.5448366108102214 and parameters: {'learning_rate': 0.12667222023936436, 'max_depth': 2, 'l2_leaf_reg': 1.743661854786636, 'subsample': 0.1650248002657289, 'random_strength': 67.18825717751852, 'min_data_in_leaf': 1.881215842114976}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:32,406] Trial 45 finished with value: 0.6870408402295647 and parameters: {'learning_rate': 0.3964980905015456, 'max_depth': 2, 'l2_leaf_reg': 1.631886347470222, 'subsample': 0.2619491156529994, 'random_strength': 54.39412085594746, 'min_data_in_leaf': 85.97758348718625}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:32,887] Trial 46 finished with value: 0.6844262295081966 and parameters: {'learning_rate': 0.2502155734686675, 'max_depth': 2, 'l2_leaf_reg': 1.633145905206284, 'subsample': 0.26336796670659673, 'random_strength': 91.75893051431537, 'min_data_in_leaf': 168.17505976026075}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:33,259] Trial 47 finished with value: 0.6813951187201887 and parameters: {'learning_rate': 0.3821926461943165, 'max_depth': 3, 'l2_leaf_reg': 1.4182487465873614, 'subsample': 0.06404107985819547, 'random_strength': 183.2983458526938, 'min_data_in_leaf': 128.7135091920957}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:33,465] Trial 48 finished with value: 0.6571290675648933 and parameters: {'learning_rate': 0.44371479163409394, 'max_depth': 2, 'l2_leaf_reg': 1.7242671111839138, 'subsample': 0.32675775045812255, 'random_strength': 56.35302305371928, 'min_data_in_leaf': 96.78601249587066}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:33,947] Trial 49 finished with value: 0.6890551860064055 and parameters: {'learning_rate': 0.3107635098305068, 'max_depth': 2, 'l2_leaf_reg': 1.8986672912597813, 'subsample': 0.48199211967888034, 'random_strength': 72.84641361895997, 'min_data_in_leaf': 63.279661823686894}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:34,256] Trial 50 finished with value: 0.6717308026284436 and parameters: {'learning_rate': 0.3091072097370531, 'max_depth': 3, 'l2_leaf_reg': 1.9095115891680818, 'subsample': 0.5843199441144652, 'random_strength': 93.12337547837173, 'min_data_in_leaf': 19.800100518248456}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:34,691] Trial 51 finished with value: 0.6807231652793428 and parameters: {'learning_rate': 0.3505023453204029, 'max_depth': 2, 'l2_leaf_reg': 1.794493735924471, 'subsample': 0.4514087068369805, 'random_strength': 81.04521931199349, 'min_data_in_leaf': 66.74455201339083}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:35,093] Trial 52 finished with value: 0.6826249298260494 and parameters: {'learning_rate': 0.4013835390753987, 'max_depth': 2, 'l2_leaf_reg': 1.637312235095453, 'subsample': 0.4920637148894522, 'random_strength': 73.66448200234686, 'min_data_in_leaf': 44.40628644379412}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:35,331] Trial 53 finished with value: 0.6791889304884107 and parameters: {'learning_rate': 0.2611383031639515, 'max_depth': 2, 'l2_leaf_reg': 1.9882952421533946, 'subsample': 0.3944558607044592, 'random_strength': 58.54102329555144, 'min_data_in_leaf': 138.53055883677268}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:35,551] Trial 54 finished with value: 0.6725420942734018 and parameters: {'learning_rate': 0.3211076327560199, 'max_depth': 2, 'l2_leaf_reg': 1.8558357563018335, 'subsample': 0.18743326687606476, 'random_strength': 45.77248158003407, 'min_data_in_leaf': 71.06199501690341}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:35,823] Trial 55 finished with value: 0.6813410999236669 and parameters: {'learning_rate': 0.53608482688251, 'max_depth': 2, 'l2_leaf_reg': 1.5218466366648697, 'subsample': 0.047591866492465607, 'random_strength': 32.98667476547375, 'min_data_in_leaf': 215.15732898423767}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:36,242] Trial 56 finished with value: 0.6799199512114347 and parameters: {'learning_rate': 0.485577458492513, 'max_depth': 3, 'l2_leaf_reg': 1.6819676353953084, 'subsample': 0.7282593060037599, 'random_strength': 52.331588063673635, 'min_data_in_leaf': 254.60496539801295}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:36,938] Trial 57 finished with value: 0.6786608588887677 and parameters: {'learning_rate': 0.10452864035779696, 'max_depth': 6, 'l2_leaf_reg': 1.3299431851743821, 'subsample': 0.5966287252077087, 'random_strength': 64.07798214325001, 'min_data_in_leaf': 103.61743401193996}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:37,403] Trial 58 finished with value: 0.6805671670725649 and parameters: {'learning_rate': 0.42643977651650716, 'max_depth': 3, 'l2_leaf_reg': 1.8094984663479463, 'subsample': 0.23950126493353124, 'random_strength': 81.83225454787828, 'min_data_in_leaf': 19.406779863042516}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:37,678] Trial 59 finished with value: 0.6523067540660503 and parameters: {'learning_rate': 0.21427323572254475, 'max_depth': 2, 'l2_leaf_reg': 1.93643308416326, 'subsample': 0.47974999362102444, 'random_strength': 70.94443517463061, 'min_data_in_leaf': 177.3742386197909}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:38,319] Trial 60 finished with value: 0.6779929442364468 and parameters: {'learning_rate': 0.3164324645582292, 'max_depth': 7, 'l2_leaf_reg': 1.5657370599545295, 'subsample': 0.3663246820168321, 'random_strength': 53.86597469615201, 'min_data_in_leaf': 88.35201438220689}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:38,598] Trial 61 finished with value: 0.6760295881647341 and parameters: {'learning_rate': 0.8267667558588878, 'max_depth': 2, 'l2_leaf_reg': 1.0454254798396376, 'subsample': 0.5427925947017784, 'random_strength': 34.06617467360066, 'min_data_in_leaf': 75.23657018208235}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:38,918] Trial 62 finished with value: 0.6808084846869333 and parameters: {'learning_rate': 0.5991752924903122, 'max_depth': 2, 'l2_leaf_reg': 1.8919161729476461, 'subsample': 0.14242240408287538, 'random_strength': 20.939674642180833, 'min_data_in_leaf': 31.623754394431792}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:39,244] Trial 63 finished with value: 0.6788451286152206 and parameters: {'learning_rate': 0.6926610639061145, 'max_depth': 2, 'l2_leaf_reg': 0.294077917269701, 'subsample': 0.1298901940042721, 'random_strength': 38.88597836449357, 'min_data_in_leaf': 152.1673516827036}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:39,528] Trial 64 finished with value: 0.6765763391613051 and parameters: {'learning_rate': 0.5598176700618825, 'max_depth': 2, 'l2_leaf_reg': 1.7704555967858315, 'subsample': 0.19768586962169246, 'random_strength': 9.864592769822892, 'min_data_in_leaf': 108.60553148005106}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:40,103] Trial 65 finished with value: 0.6812446738476328 and parameters: {'learning_rate': 0.22562450369649584, 'max_depth': 3, 'l2_leaf_reg': 0.10710287437046911, 'subsample': 0.09519395788181408, 'random_strength': 43.858016087666705, 'min_data_in_leaf': 55.640370385863875}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:40,579] Trial 66 finished with value: 0.6746114685438955 and parameters: {'learning_rate': 0.055463147369046575, 'max_depth': 2, 'l2_leaf_reg': 0.2470499555084285, 'subsample': 0.300773077657708, 'random_strength': 147.9476901781777, 'min_data_in_leaf': 201.88303288622149}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:41,046] Trial 67 finished with value: 0.6733761041038131 and parameters: {'learning_rate': 0.15526073482317332, 'max_depth': 5, 'l2_leaf_reg': 1.9720753377777467, 'subsample': 0.04702021618258975, 'random_strength': 62.39253302687313, 'min_data_in_leaf': 122.26174659685216}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:41,854] Trial 68 finished with value: 0.6823129334124935 and parameters: {'learning_rate': 0.2908703931942738, 'max_depth': 2, 'l2_leaf_reg': 1.2058009335261952, 'subsample': 0.16805605387533412, 'random_strength': 29.643022108583907, 'min_data_in_leaf': 92.44016821109804}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:42,446] Trial 69 finished with value: 0.6819252097140942 and parameters: {'learning_rate': 0.403315258152412, 'max_depth': 3, 'l2_leaf_reg': 1.8752806247969995, 'subsample': 0.11026913899338289, 'random_strength': 49.37323319233692, 'min_data_in_leaf': 144.2919980511731}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:42,960] Trial 70 finished with value: 0.6774305429343415 and parameters: {'learning_rate': 0.6288759070292825, 'max_depth': 2, 'l2_leaf_reg': 0.9348859625617738, 'subsample': 0.03263629510521153, 'random_strength': 41.38523436432595, 'min_data_in_leaf': 18.707613668263043}. Best is trial 5 with value: 0.6899674473644885.
# [I 2024-06-13 18:48:43,543] Trial 71 finished with value: 0.6904566456245784 and parameters: {'learning_rate': 0.5590146137721661, 'max_depth': 4, 'l2_leaf_reg': 0.31742644702190465, 'subsample': 0.11200708072917373, 'random_strength': 59.23813649465591, 'min_data_in_leaf': 344.6236541701154}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:44,027] Trial 72 finished with value: 0.6879263446136696 and parameters: {'learning_rate': 0.522048206115695, 'max_depth': 5, 'l2_leaf_reg': 0.5037639015008253, 'subsample': 0.0734414666923562, 'random_strength': 76.49111099542638, 'min_data_in_leaf': 325.3446460217719}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:44,669] Trial 73 finished with value: 0.6811103841291767 and parameters: {'learning_rate': 0.5287454652169289, 'max_depth': 5, 'l2_leaf_reg': 0.5177956009659126, 'subsample': 0.07034410237337851, 'random_strength': 76.26686715362692, 'min_data_in_leaf': 374.9146105380441}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:45,278] Trial 74 finished with value: 0.6752591892535915 and parameters: {'learning_rate': 0.4962894150295234, 'max_depth': 6, 'l2_leaf_reg': 0.7709490452136798, 'subsample': 0.1399977774861862, 'random_strength': 67.28331114041494, 'min_data_in_leaf': 338.4890489091787}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:45,830] Trial 75 finished with value: 0.6832408450761109 and parameters: {'learning_rate': 0.4528338420713277, 'max_depth': 4, 'l2_leaf_reg': 0.41319040827763237, 'subsample': 0.10561316465714088, 'random_strength': 86.47325702732071, 'min_data_in_leaf': 292.1102229590884}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:45,952] Trial 76 finished with value: 0.5 and parameters: {'learning_rate': 0.4653943796831175, 'max_depth': 6, 'l2_leaf_reg': 0.5898855792916812, 'subsample': 0.016146247822424256, 'random_strength': 98.77846914333173, 'min_data_in_leaf': 257.5290802143533}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:46,333] Trial 77 finished with value: 0.6697608835253779 and parameters: {'learning_rate': 0.5453191133560428, 'max_depth': 5, 'l2_leaf_reg': 0.16112345750684978, 'subsample': 0.5207339229220369, 'random_strength': 59.01894574528097, 'min_data_in_leaf': 310.5795561839329}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:46,689] Trial 78 finished with value: 0.6824487376766465 and parameters: {'learning_rate': 0.563053030127912, 'max_depth': 4, 'l2_leaf_reg': 0.46040983582278205, 'subsample': 0.21529837910572253, 'random_strength': 76.2704463302231, 'min_data_in_leaf': 240.87339285512684}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:47,255] Trial 79 finished with value: 0.6816122036034071 and parameters: {'learning_rate': 0.37043040615300377, 'max_depth': 5, 'l2_leaf_reg': 0.7069842031777026, 'subsample': 0.42697190551676956, 'random_strength': 97.72012900096351, 'min_data_in_leaf': 324.83306652616744}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:47,739] Trial 80 finished with value: 0.6824371261596371 and parameters: {'learning_rate': 0.4302438267564036, 'max_depth': 6, 'l2_leaf_reg': 0.24822519813047195, 'subsample': 0.34375504952126923, 'random_strength': 61.150310872602226, 'min_data_in_leaf': 271.87274720006934}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:48,147] Trial 81 finished with value: 0.6829904401875613 and parameters: {'learning_rate': 0.6266168427758082, 'max_depth': 3, 'l2_leaf_reg': 0.3263873056771856, 'subsample': 0.1511419625617869, 'random_strength': 52.58137759498939, 'min_data_in_leaf': 39.82752552346109}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:48,413] Trial 82 finished with value: 0.6823502922063498 and parameters: {'learning_rate': 0.6752131349226647, 'max_depth': 4, 'l2_leaf_reg': 1.6938505715674363, 'subsample': 0.07243066223010047, 'random_strength': 68.23172053525353, 'min_data_in_leaf': 61.33326515844243}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:48,703] Trial 83 finished with value: 0.6727268688484203 and parameters: {'learning_rate': 0.7241262787227137, 'max_depth': 2, 'l2_leaf_reg': 0.4215184889147021, 'subsample': 0.25401472708778206, 'random_strength': 108.56667084822958, 'min_data_in_leaf': 81.10312088613335}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:48,974] Trial 84 finished with value: 0.6848386907863117 and parameters: {'learning_rate': 0.5063646698820764, 'max_depth': 2, 'l2_leaf_reg': 0.3004322125099977, 'subsample': 0.18512083501210175, 'random_strength': 47.8650942887149, 'min_data_in_leaf': 372.66802806173934}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:49,255] Trial 85 finished with value: 0.6837557906130478 and parameters: {'learning_rate': 0.48320801944296177, 'max_depth': 3, 'l2_leaf_reg': 0.3594911791251203, 'subsample': 0.09532689930860466, 'random_strength': 24.961848950889124, 'min_data_in_leaf': 425.4319201533417}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:49,734] Trial 86 finished with value: 0.677772325413269 and parameters: {'learning_rate': 0.3442969960811032, 'max_depth': 7, 'l2_leaf_reg': 0.5035325353512319, 'subsample': 0.03447907891237194, 'random_strength': 41.78373716613331, 'min_data_in_leaf': 48.650826380024895}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:50,073] Trial 87 finished with value: 0.67278341188777 and parameters: {'learning_rate': 0.5817574502213917, 'max_depth': 5, 'l2_leaf_reg': 0.2138888115458919, 'subsample': 0.1194885961790043, 'random_strength': 85.20601415414374, 'min_data_in_leaf': 114.7265398181685}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:50,307] Trial 88 finished with value: 0.674698302497183 and parameters: {'learning_rate': 0.6038209499175854, 'max_depth': 2, 'l2_leaf_reg': 0.5598284359634224, 'subsample': 0.060314334689733934, 'random_strength': 32.49636128139955, 'min_data_in_leaf': 350.2187294313982}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:50,593] Trial 89 finished with value: 0.6788744098320268 and parameters: {'learning_rate': 0.013975436197868008, 'max_depth': 3, 'l2_leaf_reg': 0.10180319214919342, 'subsample': 0.388182025173459, 'random_strength': 51.129105633168955, 'min_data_in_leaf': 460.0281144624049}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:50,952] Trial 90 finished with value: 0.6867025916905966 and parameters: {'learning_rate': 0.3966513844404863, 'max_depth': 2, 'l2_leaf_reg': 1.8475318845028634, 'subsample': 0.18340959398451362, 'random_strength': 57.47049342180983, 'min_data_in_leaf': 70.23144402939344}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:51,337] Trial 91 finished with value: 0.6812128683879983 and parameters: {'learning_rate': 0.390578946671346, 'max_depth': 2, 'l2_leaf_reg': 1.8265085631895692, 'subsample': 0.9927191725765119, 'random_strength': 71.44761576091454, 'min_data_in_leaf': 83.84155434820413}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:51,743] Trial 92 finished with value: 0.6865072152956999 and parameters: {'learning_rate': 0.33942714509654986, 'max_depth': 2, 'l2_leaf_reg': 1.9413679246483682, 'subsample': 0.15666611601893082, 'random_strength': 65.2546088676089, 'min_data_in_leaf': 66.93323014389601}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:52,068] Trial 93 finished with value: 0.6824613588907871 and parameters: {'learning_rate': 0.4371684858023571, 'max_depth': 2, 'l2_leaf_reg': 1.9971092413540896, 'subsample': 0.2084012574601784, 'random_strength': 56.566911188635245, 'min_data_in_leaf': 100.29752791774554}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:52,358] Trial 94 finished with value: 0.6852486278215986 and parameters: {'learning_rate': 0.5214752009147985, 'max_depth': 2, 'l2_leaf_reg': 1.7816674537064048, 'subsample': 0.17623772199251084, 'random_strength': 79.9727756059018, 'min_data_in_leaf': 12.03737300328821}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:52,779] Trial 95 finished with value: 0.6804954785762464 and parameters: {'learning_rate': 0.3697105147747773, 'max_depth': 2, 'l2_leaf_reg': 0.38792835610073634, 'subsample': 0.23017666190391992, 'random_strength': 15.605016917765049, 'min_data_in_leaf': 31.505049926929132}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:52,996] Trial 96 finished with value: 0.6609866154548283 and parameters: {'learning_rate': 0.4094610203684407, 'max_depth': 3, 'l2_leaf_reg': 1.6362949517486467, 'subsample': 0.12149627632440728, 'random_strength': 38.32294207011526, 'min_data_in_leaf': 47.97260459679241}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:53,251] Trial 97 finished with value: 0.68172377513641 and parameters: {'learning_rate': 0.5766408847176302, 'max_depth': 2, 'l2_leaf_reg': 1.860662436878591, 'subsample': 0.09010711394643445, 'random_strength': 44.784143300421555, 'min_data_in_leaf': 360.00071981888215}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:53,645] Trial 98 finished with value: 0.6828935092629614 and parameters: {'learning_rate': 0.47218867123452996, 'max_depth': 2, 'l2_leaf_reg': 1.897771072230754, 'subsample': 0.46492024500383955, 'random_strength': 59.87077045417831, 'min_data_in_leaf': 388.2865559147822}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:53,998] Trial 99 finished with value: 0.6586612829615628 and parameters: {'learning_rate': 0.7594774224456792, 'max_depth': 6, 'l2_leaf_reg': 1.732464388456626, 'subsample': 0.2825725812562124, 'random_strength': 54.583193602295225, 'min_data_in_leaf': 68.95645009518684}. Best is trial 71 with value: 0.6904566456245784.
# [I 2024-06-13 18:48:54,336] A new study created in memory with name: CatBoostClassifier
# [I 2024-06-13 18:48:54,511] Trial 0 finished with value: 0.6370668243642814 and parameters: {'learning_rate': 0.37929320653056897, 'max_depth': 4, 'l2_leaf_reg': 0.42058078198671645, 'subsample': 0.22025411837125028, 'random_strength': 113.03878565753993, 'min_data_in_leaf': 482.4681682619584}. Best is trial 0 with value: 0.6370668243642814.
# [I 2024-06-13 18:48:55,035] Trial 1 finished with value: 0.6904654895666132 and parameters: {'learning_rate': 0.3998030378687129, 'max_depth': 6, 'l2_leaf_reg': 1.3384023869057193, 'subsample': 0.4785078642740879, 'random_strength': 161.93482149530794, 'min_data_in_leaf': 238.36303341401538}. Best is trial 1 with value: 0.6904654895666132.
# [I 2024-06-13 18:48:55,519] Trial 2 finished with value: 0.6953237025147139 and parameters: {'learning_rate': 0.35039492186771687, 'max_depth': 4, 'l2_leaf_reg': 0.5471249945166093, 'subsample': 0.9121046619587244, 'random_strength': 66.13677791091403, 'min_data_in_leaf': 128.58880883328254}. Best is trial 2 with value: 0.6953237025147139.
# [I 2024-06-13 18:48:56,128] Trial 3 finished with value: 0.6873182957393483 and parameters: {'learning_rate': 0.42323507266914345, 'max_depth': 4, 'l2_leaf_reg': 1.996971915988011, 'subsample': 0.975318515286958, 'random_strength': 38.23620033693985, 'min_data_in_leaf': 466.30343344113015}. Best is trial 2 with value: 0.6953237025147139.
# [I 2024-06-13 18:48:57,259] Trial 4 finished with value: 0.6910117991608234 and parameters: {'learning_rate': 0.5193676339580462, 'max_depth': 7, 'l2_leaf_reg': 0.16860561159216933, 'subsample': 0.7773593069375017, 'random_strength': 101.4880403933136, 'min_data_in_leaf': 235.38048339605703}. Best is trial 2 with value: 0.6953237025147139.
# [I 2024-06-13 18:48:57,737] Trial 5 finished with value: 0.6859671651037708 and parameters: {'learning_rate': 0.8833718522257885, 'max_depth': 3, 'l2_leaf_reg': 1.5587733216910897, 'subsample': 0.5358000495362462, 'random_strength': 167.4815500644363, 'min_data_in_leaf': 9.642057764413517}. Best is trial 2 with value: 0.6953237025147139.
# [I 2024-06-13 18:48:58,309] Trial 6 finished with value: 0.687875306243136 and parameters: {'learning_rate': 0.369060830306619, 'max_depth': 7, 'l2_leaf_reg': 1.4317997714180424, 'subsample': 0.27816229902818235, 'random_strength': 60.53619464839524, 'min_data_in_leaf': 337.18296685081543}. Best is trial 2 with value: 0.6953237025147139.
# [I 2024-06-13 18:48:59,025] Trial 7 finished with value: 0.6964264594069444 and parameters: {'learning_rate': 0.4551925904799477, 'max_depth': 7, 'l2_leaf_reg': 1.6286924258193385, 'subsample': 0.07604267355103357, 'random_strength': 190.94310706686392, 'min_data_in_leaf': 273.88725557058945}. Best is trial 7 with value: 0.6964264594069444.
# [I 2024-06-13 18:48:59,743] Trial 8 finished with value: 0.6923848948213229 and parameters: {'learning_rate': 0.4932906318164713, 'max_depth': 7, 'l2_leaf_reg': 1.507436228239173, 'subsample': 0.11907461627180223, 'random_strength': 158.19593589365545, 'min_data_in_leaf': 434.31877910290183}. Best is trial 7 with value: 0.6964264594069444.
# [I 2024-06-13 18:49:00,619] Trial 9 finished with value: 0.6829016361127538 and parameters: {'learning_rate': 0.8904283370839698, 'max_depth': 7, 'l2_leaf_reg': 1.024219358091647, 'subsample': 0.5696747902870918, 'random_strength': 182.14836416136285, 'min_data_in_leaf': 140.01849454337378}. Best is trial 7 with value: 0.6964264594069444.
# [I 2024-06-13 18:49:01,398] Trial 10 finished with value: 0.6978817831094591 and parameters: {'learning_rate': 0.010868404783238084, 'max_depth': 2, 'l2_leaf_reg': 1.9248274430609973, 'subsample': 0.09661104048475089, 'random_strength': 10.988932354158436, 'min_data_in_leaf': 346.24634162064854}. Best is trial 10 with value: 0.6978817831094591.
# [I 2024-06-13 18:49:01,638] Trial 11 finished with value: 0.5 and parameters: {'learning_rate': 0.01929961183997775, 'max_depth': 2, 'l2_leaf_reg': 1.947000245066417, 'subsample': 0.02602465249432863, 'random_strength': 23.36581074184771, 'min_data_in_leaf': 343.2322115496605}. Best is trial 10 with value: 0.6978817831094591.
# [I 2024-06-13 18:49:02,342] Trial 12 finished with value: 0.6954042409394272 and parameters: {'learning_rate': 0.11675521008880846, 'max_depth': 2, 'l2_leaf_reg': 1.740343949527976, 'subsample': 0.3411055447474177, 'random_strength': 3.603294525530444, 'min_data_in_leaf': 338.85125239177245}. Best is trial 10 with value: 0.6978817831094591.
# [I 2024-06-13 18:49:02,592] Trial 13 finished with value: 0.5 and parameters: {'learning_rate': 0.6515428079192855, 'max_depth': 5, 'l2_leaf_reg': 1.011538926015677, 'subsample': 0.02882535744178922, 'random_strength': 126.50813191739377, 'min_data_in_leaf': 287.6483073482951}. Best is trial 10 with value: 0.6978817831094591.
# [I 2024-06-13 18:49:03,036] Trial 14 finished with value: 0.6532516684970855 and parameters: {'learning_rate': 0.19948859084639275, 'max_depth': 5, 'l2_leaf_reg': 1.7393167521084685, 'subsample': 0.1670003625442953, 'random_strength': 196.75768947171764, 'min_data_in_leaf': 391.5727096622146}. Best is trial 10 with value: 0.6978817831094591.
# [I 2024-06-13 18:49:03,340] Trial 15 finished with value: 0.5541820844245445 and parameters: {'learning_rate': 0.6805659791664449, 'max_depth': 3, 'l2_leaf_reg': 1.766516814127007, 'subsample': 0.3869033883526773, 'random_strength': 72.95414951419166, 'min_data_in_leaf': 159.0899819160765}. Best is trial 10 with value: 0.6978817831094591.
# [I 2024-06-13 18:49:04,723] Trial 16 finished with value: 0.6901072906986568 and parameters: {'learning_rate': 0.2419487718258689, 'max_depth': 6, 'l2_leaf_reg': 1.2389787158421826, 'subsample': 0.7007591763576811, 'random_strength': 131.68017315355567, 'min_data_in_leaf': 199.46266327709392}. Best is trial 10 with value: 0.6978817831094591.
# [I 2024-06-13 18:49:05,075] Trial 17 finished with value: 0.6909239390611359 and parameters: {'learning_rate': 0.6297497900474481, 'max_depth': 3, 'l2_leaf_reg': 0.7181989353046077, 'subsample': 0.07069815906567717, 'random_strength': 83.03792408430682, 'min_data_in_leaf': 54.39730426988041}. Best is trial 10 with value: 0.6978817831094591.
# [I 2024-06-13 18:49:06,191] Trial 18 finished with value: 0.6966461096561628 and parameters: {'learning_rate': 0.026476931366892054, 'max_depth': 6, 'l2_leaf_reg': 1.215509585864703, 'subsample': 0.21109385929310454, 'random_strength': 36.27329209563713, 'min_data_in_leaf': 306.88152009613844}. Best is trial 10 with value: 0.6978817831094591.
# [I 2024-06-13 18:49:06,628] Trial 19 finished with value: 0.699007631438146 and parameters: {'learning_rate': 0.027550374283487205, 'max_depth': 6, 'l2_leaf_reg': 0.7771295326173532, 'subsample': 0.21973926138391772, 'random_strength': 39.965790657984, 'min_data_in_leaf': 400.4490966039718}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:07,021] Trial 20 finished with value: 0.690254287403903 and parameters: {'learning_rate': 0.13091630065191956, 'max_depth': 5, 'l2_leaf_reg': 0.1478084669660803, 'subsample': 0.3959999749398012, 'random_strength': 6.425724728412132, 'min_data_in_leaf': 402.5480006983641}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:07,650] Trial 21 finished with value: 0.6928433443158458 and parameters: {'learning_rate': 0.01392868517042941, 'max_depth': 6, 'l2_leaf_reg': 0.7664509074378993, 'subsample': 0.25150267551829975, 'random_strength': 39.46750978213884, 'min_data_in_leaf': 377.66285559920243}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:08,207] Trial 22 finished with value: 0.6924783869786826 and parameters: {'learning_rate': 0.09640949631038552, 'max_depth': 6, 'l2_leaf_reg': 0.8480756395888926, 'subsample': 0.19031898327826896, 'random_strength': 34.86810211992427, 'min_data_in_leaf': 307.4896964122436}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:08,636] Trial 23 finished with value: 0.6928951592464306 and parameters: {'learning_rate': 0.23147653929100334, 'max_depth': 5, 'l2_leaf_reg': 1.221348424288828, 'subsample': 0.29590059638737853, 'random_strength': 22.422448966133388, 'min_data_in_leaf': 417.1836070916037}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:08,974] Trial 24 finished with value: 0.6904057897552871 and parameters: {'learning_rate': 0.09362461826395943, 'max_depth': 6, 'l2_leaf_reg': 0.3809173022894686, 'subsample': 0.15633683074783652, 'random_strength': 51.41822170250412, 'min_data_in_leaf': 367.26512748277304}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:09,329] Trial 25 finished with value: 0.6979910450283011 and parameters: {'learning_rate': 0.292869294864467, 'max_depth': 2, 'l2_leaf_reg': 1.1683733919855654, 'subsample': 0.46621403396264377, 'random_strength': 15.28127917803361, 'min_data_in_leaf': 312.23227254960796}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:09,512] Trial 26 finished with value: 0.6850553349666301 and parameters: {'learning_rate': 0.1874219087629822, 'max_depth': 2, 'l2_leaf_reg': 0.5760019542624744, 'subsample': 0.460984104670013, 'random_strength': 16.87969584396178, 'min_data_in_leaf': 440.30095281344416}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:09,798] Trial 27 finished with value: 0.6158891611050097 and parameters: {'learning_rate': 0.2741018571823547, 'max_depth': 3, 'l2_leaf_reg': 0.8996195355686147, 'subsample': 0.6293792151001623, 'random_strength': 85.04597293944418, 'min_data_in_leaf': 490.50344337812146}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:10,194] Trial 28 finished with value: 0.6965137563008645 and parameters: {'learning_rate': 0.30801580721384614, 'max_depth': 2, 'l2_leaf_reg': 1.1136173712894861, 'subsample': 0.4236992247344032, 'random_strength': 51.61908204448268, 'min_data_in_leaf': 265.0826385935924}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:10,647] Trial 29 finished with value: 0.6978953000478725 and parameters: {'learning_rate': 0.14791673678410464, 'max_depth': 3, 'l2_leaf_reg': 0.2900051837247747, 'subsample': 0.3287423302121163, 'random_strength': 9.705429282046312, 'min_data_in_leaf': 454.23330366288343}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:10,840] Trial 30 finished with value: 0.6878426403086368 and parameters: {'learning_rate': 0.15198504305041888, 'max_depth': 3, 'l2_leaf_reg': 0.26690351607771773, 'subsample': 0.3208327826524472, 'random_strength': 24.582385620780453, 'min_data_in_leaf': 457.1332155687675}. Best is trial 19 with value: 0.699007631438146.
# [I 2024-06-13 18:49:11,335] Trial 31 finished with value: 0.6996581340992932 and parameters: {'learning_rate': 0.045252127955393226, 'max_depth': 2, 'l2_leaf_reg': 0.6031780371380268, 'subsample': 0.3485813091553137, 'random_strength': 9.674129058035748, 'min_data_in_leaf': 359.91076959293184}. Best is trial 31 with value: 0.6996581340992932.
# [I 2024-06-13 18:49:11,633] Trial 32 finished with value: 0.6987305342006702 and parameters: {'learning_rate': 0.07766515467473463, 'max_depth': 2, 'l2_leaf_reg': 0.53769591454903, 'subsample': 0.34872148364402056, 'random_strength': 1.2763563989142952, 'min_data_in_leaf': 413.1375244872625}. Best is trial 31 with value: 0.6996581340992932.
# [I 2024-06-13 18:49:11,830] Trial 33 finished with value: 0.6998040043930049 and parameters: {'learning_rate': 0.0799884998052279, 'max_depth': 2, 'l2_leaf_reg': 0.5709599379936029, 'subsample': 0.47405236287213776, 'random_strength': 1.1560120426083802, 'min_data_in_leaf': 411.83893748461145}. Best is trial 33 with value: 0.6998040043930049.
# [I 2024-06-13 18:49:12,424] Trial 34 finished with value: 0.6978502435864942 and parameters: {'learning_rate': 0.08068074444690637, 'max_depth': 4, 'l2_leaf_reg': 0.519260474667741, 'subsample': 0.5879263911561461, 'random_strength': 3.3002938869762604, 'min_data_in_leaf': 498.43888401141476}. Best is trial 33 with value: 0.6998040043930049.
# [I 2024-06-13 18:49:13,081] Trial 35 finished with value: 0.6955844667849399 and parameters: {'learning_rate': 0.061411064476065765, 'max_depth': 4, 'l2_leaf_reg': 0.654680035071424, 'subsample': 0.36493872980080544, 'random_strength': 28.520903563192853, 'min_data_in_leaf': 418.52208616767695}. Best is trial 33 with value: 0.6998040043930049.
# [I 2024-06-13 18:49:13,622] Trial 36 finished with value: 0.6965244572104419 and parameters: {'learning_rate': 0.1892983124041327, 'max_depth': 2, 'l2_leaf_reg': 0.4440015277901427, 'subsample': 0.23693676936649774, 'random_strength': 49.98164721065084, 'min_data_in_leaf': 367.1208098620725}. Best is trial 33 with value: 0.6998040043930049.
# [I 2024-06-13 18:49:14,191] Trial 37 finished with value: 0.697167074990848 and parameters: {'learning_rate': 0.06078041284568651, 'max_depth': 3, 'l2_leaf_reg': 0.06386554426789909, 'subsample': 0.5148333252024485, 'random_strength': 1.3073318014846973, 'min_data_in_leaf': 472.2534706534052}. Best is trial 33 with value: 0.6998040043930049.
# [I 2024-06-13 18:49:14,955] Trial 38 finished with value: 0.6877801244684746 and parameters: {'learning_rate': 0.14037498107818175, 'max_depth': 2, 'l2_leaf_reg': 0.6148945458211748, 'subsample': 0.862471621487239, 'random_strength': 31.779851927264993, 'min_data_in_leaf': 398.5811940560965}. Best is trial 33 with value: 0.6998040043930049.
# ...
# [I 2024-06-13 18:50:11,028] Trial 54 finished with value: 0.6582157830727625 and parameters: {'learning_rate': 0.3728992579402194, 'max_depth': 5, 'l2_leaf_reg': 0.2247482352600609, 'subsample': 0.1767083908429139, 'random_strength': 174.01752035084965, 'min_data_in_leaf': 330.0472816071019}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:11,196] Trial 55 finished with value: 0.5 and parameters: {'learning_rate': 0.42870554637211283, 'max_depth': 4, 'l2_leaf_reg': 0.7534361603259732, 'subsample': 0.038873110045117454, 'random_strength': 68.26331334225988, 'min_data_in_leaf': 403.8311824878541}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:11,962] Trial 56 finished with value: 0.6449758765262198 and parameters: {'learning_rate': 0.6519581796992279, 'max_depth': 7, 'l2_leaf_reg': 0.8859194693606041, 'subsample': 0.23018348344158074, 'random_strength': 135.36310323085635, 'min_data_in_leaf': 288.25505213284094}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:12,879] Trial 57 finished with value: 0.6549923188939208 and parameters: {'learning_rate': 0.5691805376680914, 'max_depth': 3, 'l2_leaf_reg': 0.18212458313511862, 'subsample': 0.10743360252839299, 'random_strength': 107.47699610020106, 'min_data_in_leaf': 217.41677477433012}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:13,399] Trial 58 finished with value: 0.6499795970619769 and parameters: {'learning_rate': 0.7314364392222119, 'max_depth': 4, 'l2_leaf_reg': 1.1189495021027758, 'subsample': 0.15278648752455784, 'random_strength': 85.40237730510181, 'min_data_in_leaf': 341.1645030268495}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:13,593] Trial 59 finished with value: 0.5 and parameters: {'learning_rate': 0.5263516536217591, 'max_depth': 5, 'l2_leaf_reg': 0.31026501782725296, 'subsample': 0.01300052953857337, 'random_strength': 117.6391664844824, 'min_data_in_leaf': 319.69214785773016}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:14,314] Trial 60 finished with value: 0.6593009393352642 and parameters: {'learning_rate': 0.4745898459838107, 'max_depth': 4, 'l2_leaf_reg': 0.41361676787072943, 'subsample': 0.08053793169953678, 'random_strength': 68.65767939306986, 'min_data_in_leaf': 240.44447363546166}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:15,133] Trial 61 finished with value: 0.6560324686754893 and parameters: {'learning_rate': 0.4249747712320711, 'max_depth': 4, 'l2_leaf_reg': 0.45904783293205437, 'subsample': 0.4865054961972178, 'random_strength': 83.78036698442283, 'min_data_in_leaf': 380.639256560233}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:15,930] Trial 62 finished with value: 0.6557724312300971 and parameters: {'learning_rate': 0.3547767992770058, 'max_depth': 4, 'l2_leaf_reg': 0.6765374872786413, 'subsample': 0.6119473161155885, 'random_strength': 95.37474035751163, 'min_data_in_leaf': 353.550897488499}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:16,402] Trial 63 finished with value: 0.6593899521531101 and parameters: {'learning_rate': 0.3031401865929112, 'max_depth': 4, 'l2_leaf_reg': 0.3667694139343752, 'subsample': 0.3437880366066256, 'random_strength': 48.2153777283647, 'min_data_in_leaf': 271.7494273107619}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:16,814] Trial 64 finished with value: 0.6500536077195116 and parameters: {'learning_rate': 0.5463068091626795, 'max_depth': 3, 'l2_leaf_reg': 0.607294933528913, 'subsample': 0.4203153225516527, 'random_strength': 80.97984014652158, 'min_data_in_leaf': 393.8143940036445}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:17,905] Trial 65 finished with value: 0.6564835336288425 and parameters: {'learning_rate': 0.4874586621181638, 'max_depth': 5, 'l2_leaf_reg': 0.09935202952042006, 'subsample': 0.568053947783373, 'random_strength': 74.60386803524945, 'min_data_in_leaf': 292.91809843316935}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:18,211] Trial 66 finished with value: 0.6602730793234226 and parameters: {'learning_rate': 0.895717917208336, 'max_depth': 3, 'l2_leaf_reg': 0.46461949478112835, 'subsample': 0.19945249417659927, 'random_strength': 105.36014315407311, 'min_data_in_leaf': 332.2647364443957}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:18,535] Trial 67 finished with value: 0.6546717727352738 and parameters: {'learning_rate': 0.8442880255941181, 'max_depth': 3, 'l2_leaf_reg': 0.5314104651993921, 'subsample': 0.1959959956376044, 'random_strength': 104.59445457411765, 'min_data_in_leaf': 323.34255116630476}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:18,727] Trial 68 finished with value: 0.6329366428765743 and parameters: {'learning_rate': 0.057510885877797346, 'max_depth': 3, 'l2_leaf_reg': 0.7376375093240838, 'subsample': 0.1381144726085448, 'random_strength': 117.39354548961191, 'min_data_in_leaf': 258.9040635568054}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:19,117] Trial 69 finished with value: 0.6549168080203549 and parameters: {'learning_rate': 0.3966729862080178, 'max_depth': 2, 'l2_leaf_reg': 0.2374971387255112, 'subsample': 0.2514207387530497, 'random_strength': 93.58226153912918, 'min_data_in_leaf': 190.52995181300395}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:19,566] Trial 70 finished with value: 0.6477102702789201 and parameters: {'learning_rate': 0.7972472982039593, 'max_depth': 6, 'l2_leaf_reg': 0.471205724532728, 'subsample': 0.8347958896516902, 'random_strength': 124.09184540586752, 'min_data_in_leaf': 342.73258651827894}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:19,831] Trial 71 finished with value: 0.6612897257205038 and parameters: {'learning_rate': 0.8789849560042036, 'max_depth': 4, 'l2_leaf_reg': 0.4053935534398209, 'subsample': 0.1040726277131426, 'random_strength': 112.03681464954691, 'min_data_in_leaf': 362.70575725801865}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:20,060] Trial 72 finished with value: 0.6540866884831416 and parameters: {'learning_rate': 0.8915623728241128, 'max_depth': 3, 'l2_leaf_reg': 0.32642254593423703, 'subsample': 0.08982074948282834, 'random_strength': 111.84025926217473, 'min_data_in_leaf': 359.357918628327}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:20,346] Trial 73 finished with value: 0.6536261221615912 and parameters: {'learning_rate': 0.8287845791472923, 'max_depth': 4, 'l2_leaf_reg': 0.655906760889118, 'subsample': 0.12115579327681916, 'random_strength': 127.43808194624818, 'min_data_in_leaf': 306.4320846255059}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:20,979] Trial 74 finished with value: 0.6542002048294955 and parameters: {'learning_rate': 0.11861404016434385, 'max_depth': 4, 'l2_leaf_reg': 0.39420589531939143, 'subsample': 0.3066696271156602, 'random_strength': 107.8181212482105, 'min_data_in_leaf': 330.61119392193046}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:21,298] Trial 75 finished with value: 0.6622868693091805 and parameters: {'learning_rate': 0.894900421508266, 'max_depth': 3, 'l2_leaf_reg': 0.558780459340158, 'subsample': 0.21024508284993226, 'random_strength': 138.45182318625075, 'min_data_in_leaf': 418.6147179483366}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:21,582] Trial 76 finished with value: 0.6528125050007201 and parameters: {'learning_rate': 0.8892114465783572, 'max_depth': 3, 'l2_leaf_reg': 0.06808210726316632, 'subsample': 0.7185585441652442, 'random_strength': 154.0152014578675, 'min_data_in_leaf': 411.7694506045327}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:21,905] Trial 77 finished with value: 0.6628314477284729 and parameters: {'learning_rate': 0.7704454872639215, 'max_depth': 3, 'l2_leaf_reg': 0.29290248708792066, 'subsample': 0.2272617525613543, 'random_strength': 143.93241467474783, 'min_data_in_leaf': 428.4229814190361}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:22,227] Trial 78 finished with value: 0.6563895200908931 and parameters: {'learning_rate': 0.7769645700444382, 'max_depth': 3, 'l2_leaf_reg': 0.1734203361869435, 'subsample': 0.203449573304878, 'random_strength': 139.8647936410706, 'min_data_in_leaf': 454.3019923431609}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:22,508] Trial 79 finished with value: 0.645053387687827 and parameters: {'learning_rate': 0.864142112858401, 'max_depth': 5, 'l2_leaf_reg': 1.3139893323189955, 'subsample': 0.16440323812639238, 'random_strength': 199.65691017932903, 'min_data_in_leaf': 423.5390604822053}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:22,803] Trial 80 finished with value: 0.6592239282456673 and parameters: {'learning_rate': 0.8292964279636974, 'max_depth': 2, 'l2_leaf_reg': 0.2788800329320909, 'subsample': 0.21808528434412489, 'random_strength': 143.3623268422399, 'min_data_in_leaf': 443.34695388939116}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:23,071] Trial 81 finished with value: 0.6552868613080283 and parameters: {'learning_rate': 0.8629254917025287, 'max_depth': 3, 'l2_leaf_reg': 0.46345987587741855, 'subsample': 0.2881517395864843, 'random_strength': 168.47709814878237, 'min_data_in_leaf': 479.49920917397304}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:23,215] Trial 82 finished with value: 0.5 and parameters: {'learning_rate': 0.7971805832521014, 'max_depth': 3, 'l2_leaf_reg': 0.5244941549465568, 'subsample': 0.054013374685339864, 'random_strength': 101.9877356388263, 'min_data_in_leaf': 395.97444998910055}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:23,510] Trial 83 finished with value: 0.6577947224400313 and parameters: {'learning_rate': 0.7446851325354393, 'max_depth': 4, 'l2_leaf_reg': 0.28333836974145205, 'subsample': 0.2519604865483888, 'random_strength': 156.41114246094065, 'min_data_in_leaf': 384.7034864402229}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:23,865] Trial 84 finished with value: 0.6565540437823045 and parameters: {'learning_rate': 0.8392225247972938, 'max_depth': 3, 'l2_leaf_reg': 0.3860104597704438, 'subsample': 0.1500353069534025, 'random_strength': 95.33232191490603, 'min_data_in_leaf': 371.5750208056075}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:24,113] Trial 85 finished with value: 0.650406158486822 and parameters: {'learning_rate': 0.8895995863998615, 'max_depth': 3, 'l2_leaf_reg': 0.2122506741809577, 'subsample': 0.23391749938102674, 'random_strength': 135.09458400161367, 'min_data_in_leaf': 425.95781311793075}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:24,497] Trial 86 finished with value: 0.6489884543374245 and parameters: {'learning_rate': 0.7098828622427366, 'max_depth': 4, 'l2_leaf_reg': 0.12561912952470633, 'subsample': 0.8913711664838562, 'random_strength': 118.84408141832074, 'min_data_in_leaf': 447.6237194653649}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:24,756] Trial 87 finished with value: 0.6446728328879359 and parameters: {'learning_rate': 0.8999235560924466, 'max_depth': 3, 'l2_leaf_reg': 0.034179472871674464, 'subsample': 0.34626452118894074, 'random_strength': 147.74574418379615, 'min_data_in_leaf': 313.79344480990187}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:25,199] Trial 88 finished with value: 0.6568755900849723 and parameters: {'learning_rate': 0.7745403099580217, 'max_depth': 4, 'l2_leaf_reg': 0.2568459264143656, 'subsample': 0.1943832226282312, 'random_strength': 179.0536123229605, 'min_data_in_leaf': 277.25384151712325}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:25,416] Trial 89 finished with value: 0.6122661663279512 and parameters: {'learning_rate': 0.8668383441047751, 'max_depth': 2, 'l2_leaf_reg': 0.43718393944574185, 'subsample': 0.034758450089022064, 'random_strength': 90.08610976236086, 'min_data_in_leaf': 226.63631367061637}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:25,747] Trial 90 finished with value: 0.657891736410043 and parameters: {'learning_rate': 0.823350889122049, 'max_depth': 3, 'l2_leaf_reg': 0.34997294396673867, 'subsample': 0.07557799986931937, 'random_strength': 71.86582930442293, 'min_data_in_leaf': 349.0641106288555}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:26,112] Trial 91 finished with value: 0.6346828943367846 and parameters: {'learning_rate': 0.44090994948228796, 'max_depth': 4, 'l2_leaf_reg': 0.5859016081752465, 'subsample': 0.09727104114009613, 'random_strength': 130.05222182619633, 'min_data_in_leaf': 368.5424612684988}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:27,135] Trial 92 finished with value: 0.6562895056888192 and parameters: {'learning_rate': 0.5946690400912674, 'max_depth': 4, 'l2_leaf_reg': 0.5627979687986986, 'subsample': 0.13494233034638575, 'random_strength': 136.8738801225745, 'min_data_in_leaf': 406.98718783137485}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:28,104] Trial 93 finished with value: 0.6614582499879983 and parameters: {'learning_rate': 0.8526082952755397, 'max_depth': 7, 'l2_leaf_reg': 0.4944870564175722, 'subsample': 0.06537616987921918, 'random_strength': 111.1912420541156, 'min_data_in_leaf': 298.70327732487044}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:28,523] Trial 94 finished with value: 0.6505646813141093 and parameters: {'learning_rate': 0.8473389322636964, 'max_depth': 3, 'l2_leaf_reg': 0.4885176270184646, 'subsample': 0.061266598824419795, 'random_strength': 110.1197184363313, 'min_data_in_leaf': 297.46539026812354}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:28,684] Trial 95 finished with value: 0.5 and parameters: {'learning_rate': 0.8167845688386568, 'max_depth': 4, 'l2_leaf_reg': 0.714638580211405, 'subsample': 0.032780867484376, 'random_strength': 98.97234234756122, 'min_data_in_leaf': 279.50850833812285}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:29,243] Trial 96 finished with value: 0.6587678625722104 and parameters: {'learning_rate': 0.8769941065201617, 'max_depth': 3, 'l2_leaf_reg': 0.4131809203858283, 'subsample': 0.16411609949895872, 'random_strength': 80.94427396639225, 'min_data_in_leaf': 265.80566390505123}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:30,000] Trial 97 finished with value: 0.6464305860043846 and parameters: {'learning_rate': 0.7736215189794872, 'max_depth': 5, 'l2_leaf_reg': 0.3256211134786454, 'subsample': 0.7938677252992674, 'random_strength': 103.47983004567429, 'min_data_in_leaf': 247.13775696106367}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:30,571] Trial 98 finished with value: 0.6573821630314767 and parameters: {'learning_rate': 0.5219333240902394, 'max_depth': 4, 'l2_leaf_reg': 0.5224179712905048, 'subsample': 0.09347955000720372, 'random_strength': 114.19549111902334, 'min_data_in_leaf': 333.8264754549128}. Best is trial 23 with value: 0.6661159206925797.
# [I 2024-06-13 18:50:31,006] Trial 99 finished with value: 0.651423805027924 and parameters: {'learning_rate': 0.8563883423870736, 'max_depth': 2, 'l2_leaf_reg': 0.19019634454053397, 'subsample': 0.12993893274616045, 'random_strength': 63.490277711803046, 'min_data_in_leaf': 306.6866032179056}. Best is trial 23 with value: 0.6661159206925797.

# %%
res_Laptop
# Out:
#        precision    recall        f1   roc_auc
# train   0.625231  0.732756  0.674737  0.662935
# valid   0.645289  0.742259  0.690385  0.683781
# test    0.607812  0.723721  0.660722  0.628712

# %%
res_Phone
# Out:
#        precision    recall        f1   roc_auc
# train   0.622988  0.561593  0.590699  0.668652
# valid   0.619469  0.553360  0.584551  0.642531
# test    0.610811  0.578893  0.594424  0.653939

# %%
res_Charger
# Out:
#        precision    recall        f1   roc_auc
# train   0.600998  0.113733  0.191270  0.678690
# valid   0.598726  0.141353  0.228710  0.700032
# test    0.560000  0.124444  0.203636  0.669407

# %% [markdown]
# # Калибровка

# %%
# калиброваться будем на изотонике
from sklearn.isotonic import IsotonicRegression

# функция для калибровки
def calibrate(model, X_valid, y_valid):
  y_pred = model.predict_proba(X_valid)[:, 1]

  iso_reg = IsotonicRegression(out_of_bounds='clip')
  iso_reg.fit(y_pred, y_valid)
  y_pred_iso = iso_reg.transform(y_pred)
  return iso_reg

# %%
# обучаем калибровку на валидационном датасете (можно и на трейне)
iso_reg_Laptop = calibrate(model_Laptop, X_valid_Laptop, y_valid_Laptop)
iso_reg_Charger = calibrate(model_Charger, X_valid_Charger, y_valid_Charger)
iso_reg_Phone = calibrate(model_Phone, X_valid_Phone, y_valid_Phone)

# %%
# сборка датасета для удобного хранения тестовых данных
cols = X_test_Charger.columns.tolist()

X_test_Charger['product'] = 'Charger'
X_test_Laptop['product'] = 'Laptop'
X_test_Phone['product'] = 'Phone'

X_test = pd.concat([X_test_Charger, X_test_Laptop, X_test_Phone])
y_test = pd.concat([y_test_Charger, y_test_Laptop, y_test_Phone])

test_df = X_test[['product']]
test_df['NPV'] = test_df['product'].map(npv_values)
test_df['target'] = y_test
test_df['predict_Charger'] = model_Charger.predict_proba(X_test[cols])[:, 1]
test_df['predict_Laptop'] = model_Laptop.predict_proba(X_test[cols])[:, 1]
test_df['predict_Phone'] = model_Phone.predict_proba(X_test[cols])[:, 1]

# %%
# проверим, что сборка прошла удачно, нигде не ошиблись, и ROC_AUC примерно ожидаемый
for product in ['Charger', 'Laptop', 'Phone']:
  tmp = test_df[test_df['product'] == product]
  print(f'ROC_AUC for {product}:', roc_auc_score(tmp['target'], tmp[f'predict_{product}']))
# Out:
# ROC_AUC for Charger: 0.6694071278825997
# ROC_AUC for Laptop: 0.6287115021998743
# ROC_AUC for Phone: 0.6539391689613218

# %%
# применяем калибровку к тестовым семплам
test_df['predict_Charger_calibrated'] = iso_reg_Charger.transform(test_df['predict_Charger'])
test_df['predict_Laptop_calibrated'] = iso_reg_Laptop.transform(test_df['predict_Laptop'])
test_df['predict_Phone_calibrated'] = iso_reg_Phone.transform(test_df['predict_Phone'])

# %%
# Названия продуктов и их соответствие скорам
product_scores = {
    'predict_Charger_calibrated': 'Charger',
    'predict_Laptop_calibrated': 'Laptop',
    'predict_Phone_calibrated': 'Phone'
}

# Вычисление максимального скора и соответствующего продукта
test_df['Max_Score_Product'] = test_df[
    ['predict_Charger_calibrated', 'predict_Laptop_calibrated', 'predict_Phone_calibrated']
].idxmax(axis=1).map(product_scores)

# Вычисление максимального значения скор * NPV и соответствующего продукта
def calculate_max_score_npv_product(row):
    scores_with_npv = {
        'Charger': row['predict_Charger_calibrated'] * npv_values['Charger'],
        'Laptop': row['predict_Laptop_calibrated'] * npv_values['Laptop'],
        'Phone': row['predict_Phone_calibrated'] * npv_values['Phone']
    }
    max_product = max(scores_with_npv, key=scores_with_npv.get)
    return max_product

test_df['Max_Score_NPV_Product'] = test_df.apply(calculate_max_score_npv_product, axis=1)

# %%
test_df[['product', 'NPV', 'target', 'predict_Charger_calibrated','predict_Laptop_calibrated',
         'predict_Phone_calibrated',	'Max_Score_Product',	'Max_Score_NPV_Product']].sample(6)
# Out:
#       product    NPV  target  predict_Charger_calibrated  \
# 5623  Charger  200.0       0                    0.339483
# 5685   Laptop  100.0       1                    0.381944
# 8991   Laptop  100.0       1                    0.210280
# 8904    Phone  300.0       0                    0.217105
# 2983   Laptop  100.0       1                    0.536765
# 2698  Charger  200.0       0                    0.082192
#
#       predict_Laptop_calibrated  predict_Phone_calibrated Max_Score_Product  \
# 5623                   0.684211                  0.350000            Laptop
# 5685                   0.666667                  0.622449            Laptop
# 8991                   0.222222                  0.320988             Phone
# 8904                   0.438596                  0.474359             Phone
# 2983                   0.684211                  0.320988            Laptop
# 2698                   0.829412                  0.488789            Laptop
#
#      Max_Score_NPV_Product
# 5623                 Phone
# 5685                 Phone
# 8991                 Phone
# 8904                 Phone
# 2983               Charger
# 2698                 Phone

# %%
# вспомним, какой мы задали NPV
npv_values
# Out:
# {'Laptop': 100.0, 'Phone': 300.0, 'Charger': 200.0}

# %%
test_df['Max_Score_Product'].value_counts()
# Out:
# Max_Score_Product
# Laptop     3188
# Phone      2249
# Charger     563
# Name: count, dtype: int64

# %%
test_df['Max_Score_NPV_Product'].value_counts()
# Out:
# Max_Score_NPV_Product
# Phone      5623
# Charger     364
# Laptop       13
# Name: count, dtype: int64
